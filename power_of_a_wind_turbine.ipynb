# %% [markdown]
# <a href="https://colab.research.google.com/github/abegpatel/power-output-of-a-wind-turbine/blob/master/power_of_a_wind_turbine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %%
pip install flask

# %%
df = pd.read_csv('/content/T1.csv',index_col='Date/Time',parse_dates=True)

# %%
df.head()
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-01-01 00:00:00           380.047791  ...          259.994904
# 2018-01-01 00:10:00           453.769196  ...          268.641113
# 2018-01-01 00:20:00           306.376587  ...          272.564789
# 2018-01-01 00:30:00           419.645905  ...          271.258087
# 2018-01-01 00:40:00           380.650696  ...          265.674286
#
# [5 rows x 4 columns]

# %%
df.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:10:00',
#                '2018-01-01 00:20:00', '2018-01-01 00:30:00',
#                '2018-01-01 00:40:00', '2018-01-01 00:50:00',
#                '2018-01-01 01:00:00', '2018-01-01 01:10:00',
#                '2018-01-01 01:20:00', '2018-01-01 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=50530, freq=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 50530 entries, 2018-01-01 00:00:00 to 2018-12-31 23:50:00
# Data columns (total 4 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   LV ActivePower (kW)            50530 non-null  float64
#  1   Wind Speed (m/s)               50530 non-null  float64
#  2   Theoretical_Power_Curve (KWh)  50530 non-null  float64
#  3   Wind Direction (°)             50530 non-null  float64
# dtypes: float64(4)
# memory usage: 1.9 MB

# %%
df['LV ActivePower (kW)'].plot(figsize=(12,8))

# %%
df['Wind Speed (m/s)'].plot(figsize=(12,8))

# %%
df['Theoretical_Power_Curve (KWh)'].plot(figsize=(12,8))

# %%
df.head
# Out:
# <bound method NDFrame.head of                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-01-01 00:00:00           380.047791  ...          259.994904
# 2018-01-01 00:10:00           453.769196  ...          268.641113
# 2018-01-01 00:20:00           306.376587  ...          272.564789
# 2018-01-01 00:30:00           419.645905  ...          271.258087
# 2018-01-01 00:40:00           380.650696  ...          265.674286
# ...                                  ...  ...                 ...
# 2018-12-31 23:10:00          2963.980957  ...           80.502724
# 2018-12-31 23:20:00          1684.353027  ...           84.062599
# 2018-12-31 23:30:00          2201.106934  ...           84.742500
# 2018-12-31 23:40:00          2515.694092  ...           84.297913
# 2018-12-31 23:50:00          2820.466064  ...           82.274620
#
# [50530 rows x 4 columns]>

# %%
df['Wind Direction (°)'].plot(figsize=(12,8))

# %%
df.head()
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-01-01 00:00:00           380.047791  ...          259.994904
# 2018-01-01 00:10:00           453.769196  ...          268.641113
# 2018-01-01 00:20:00           306.376587  ...          272.564789
# 2018-01-01 00:30:00           419.645905  ...          271.258087
# 2018-01-01 00:40:00           380.650696  ...          265.674286
#
# [5 rows x 4 columns]

# %%
#WANT TO VISUALIZE THE TERM AND FIX THE DATE
#upto one year full
x=input("input the visulize term")
#using date
y=input("enter the start date ")
z=input("enter the end date ")
LVA=df['LV ActivePower (kW)']
WS=df['Wind Speed (m/s)']
WD=df['Wind Direction (°)']
WP=df['Theoretical_Power_Curve (KWh)']
if(x=='LVA'):
  print(LVA[y:z].plot())
elif(x=='WS'):
  print(WS[y:z].plot())
elif(x=='WD'):
  print(WD[y:z].plot())
else:
  print(WP[y:z].plot())
# Out:
# input the visulize termLVA
# enter the start date 2018-01-01 00:00:00
# enter the end date 2018-01-01 00:40:00
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# **Train Test Split**

# %%
len(df)
# Out:
# 50530

# %%
df.head(3)
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-01-01 00:00:00           380.047791  ...          259.994904
# 2018-01-01 00:10:00           453.769196  ...          268.641113
# 2018-01-01 00:20:00           306.376587  ...          272.564789
#
# [3 rows x 4 columns]

# %%
df.tail()
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-12-31 23:10:00          2963.980957  ...           80.502724
# 2018-12-31 23:20:00          1684.353027  ...           84.062599
# 2018-12-31 23:30:00          2201.106934  ...           84.742500
# 2018-12-31 23:40:00          2515.694092  ...           84.297913
# 2018-12-31 23:50:00          2820.466064  ...           82.274620
#
# [5 rows x 4 columns]

# %%
len(df)
# Out:
# 50530

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-01-01 00:00:00           380.047791  ...          259.994904
# 2018-01-01 00:10:00           453.769196  ...          268.641113
# 2018-01-01 00:20:00           306.376587  ...          272.564789
# 2018-01-01 00:30:00           419.645905  ...          271.258087
# 2018-01-01 00:40:00           380.650696  ...          265.674286
#
# [5 rows x 4 columns]

# %%
len(df)
# Out:
# 50530

# %%
df1=df.loc['2018-12-01 00:00:00':'2018-12-31 23:50:00	']

# %%
df1 = df1.round(2)

# %%
24*60/10#rows per day
# Out:
# 144.0

# %%
test_days = 3

# %%
test_ind = test_days*144

# %%
train = df1.iloc[:-test_ind]
test = df1.iloc[-test_ind:]

# %%
train
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-12-01 00:00:00               728.57  ...              223.79
# 2018-12-01 00:10:00               346.69  ...              229.62
# 2018-12-01 00:20:00               197.96  ...              230.74
# 2018-12-01 00:30:00               244.26  ...              233.21
# 2018-12-01 00:40:00               140.94  ...              231.76
# ...                                  ...  ...                 ...
# 2018-12-28 23:10:00               238.71  ...              223.50
# 2018-12-28 23:20:00               182.10  ...              220.60
# 2018-12-28 23:30:00               172.83  ...              217.52
# 2018-12-28 23:40:00               144.55  ...              215.60
# 2018-12-28 23:50:00               209.61  ...              214.38
#
# [3877 rows x 4 columns]

# %%
test
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-12-29 00:00:00               444.11  ...              206.05
# 2018-12-29 00:10:00               506.88  ...              210.68
# 2018-12-29 00:20:00               375.30  ...              213.28
# 2018-12-29 00:30:00               442.25  ...              207.25
# 2018-12-29 00:40:00               481.73  ...              206.86
# ...                                  ...  ...                 ...
# 2018-12-31 23:10:00              2963.98  ...               80.50
# 2018-12-31 23:20:00              1684.35  ...               84.06
# 2018-12-31 23:30:00              2201.11  ...               84.74
# 2018-12-31 23:40:00              2515.69  ...               84.30
# 2018-12-31 23:50:00              2820.47  ...               82.27
#
# [432 rows x 4 columns]

# %% [markdown]
# **Scale Data**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# **Time Series Generator**

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator
length = 144 # Length of the output sequences (in number of timesteps)
batch_size = 1 #Number of timeseries samples in each batch
generator = TimeseriesGenerator(scaled_train, scaled_train, length=length, batch_size=batch_size)

# %%
len(scaled_train)
# Out:
# 3877

# %%
len(generator)
# Out:
# 3733

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [2.02372895e-01 2.86316776e-01 2.12358333e-01 6.21673426e-01
#  9.64387164e-02 2.28209934e-01 1.03766667e-01 6.37868770e-01
#  5.51807550e-02 1.90721649e-01 5.28055556e-02 6.40980054e-01
#  6.80244557e-02 2.01030928e-01 6.56416667e-02 6.47841547e-01
#  3.93633075e-02 1.73851921e-01 3.51111111e-02 6.43813545e-01
#  6.60493553e-03 1.26991565e-01 0.00000000e+00 6.69037169e-01
#  2.66305675e-04 1.41518276e-01 9.01944444e-03 6.94371910e-01
#  1.01029715e-02 1.62136832e-01 2.30861111e-02 6.62509028e-01
#  7.77279688e-03 1.36363636e-01 6.90277778e-03 6.58231013e-01
#  5.46481436e-04 9.51265230e-02 0.00000000e+00 6.71342852e-01
#  2.66305675e-04 1.05904405e-01 0.00000000e+00 6.00866715e-01
#  2.66305675e-04 1.35426429e-01 6.63888889e-03 5.64864715e-01
#  2.66305675e-04 1.63074039e-01 2.38722222e-02 5.85254736e-01
#  2.66305675e-04 1.47141518e-01 1.20611111e-02 6.06394800e-01
#  2.66305675e-04 1.15745080e-01 0.00000000e+00 0.00000000e+00
# ...

# %% [markdown]
# **### Create the Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM

# %%
scaled_train.shape
# Out:
# (3877, 4)

# %%
# define model
model = Sequential()

# Simple RNN layer
model.add(LSTM(100,input_shape=(length,scaled_train.shape[1])))

# Final Prediction (one neuron per feature)
model.add(Dense(scaled_train.shape[1]))

model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 100)               42000
# _________________________________________________________________
# dense (Dense)                (None, 4)                 404
# ...
# Total params: 42,404
# Trainable params: 42,404
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **EarlyStopping**

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=1)
validation_generator = TimeseriesGenerator(scaled_test,scaled_test, 
                                           length=length, batch_size=batch_size)

# %%
model.fit_generator(generator,epochs=10,
                    validation_data=validation_generator,
                   callbacks=[early_stop])
# Out:
# WARNING:tensorflow:From <ipython-input-51-d9cc3a10b77d>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# 3733/3733 [==============================] - 174s 47ms/step - loss: 0.0101 - val_loss: 0.0120
# Epoch 2/10
# 3733/3733 [==============================] - 173s 46ms/step - loss: 0.0068 - val_loss: 0.0125

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()

# %% [markdown]
# **Evaluate on Test Data¶**

# %%
first_eval_batch = scaled_train[-length:]

# %%
first_eval_batch

# %%
first_eval_batch = first_eval_batch.reshape((1, length, scaled_train.shape[1]))

# %%
model.predict(first_eval_batch)
# Out:
# array([[0.05230466, 0.20145035, 0.07502773, 0.6258034 ]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.12346319, 0.25351453, 0.14597778, 0.57239291])

# %%
n_features = scaled_train.shape[1]
test_predictions = []

first_eval_batch = scaled_train[-length:]
current_batch = first_eval_batch.reshape((1, length, n_features))

for i in range(len(test)+72):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.05230466, 0.20145035, 0.07502773, 0.6258034 ], dtype=float32),
#  array([0.05306742, 0.20511474, 0.08179404, 0.6442136 ], dtype=float32),
#  array([0.05330097, 0.20861626, 0.08834156, 0.6577008 ], dtype=float32),
#  array([0.05293147, 0.21198875, 0.09431408, 0.6695831 ], dtype=float32),
#  array([0.05221829, 0.2153431 , 0.09972133, 0.6806306 ], dtype=float32),
#  array([0.05137388, 0.21870722, 0.10465673, 0.6910378 ], dtype=float32),
#  array([0.05054106, 0.22208077, 0.10921557, 0.70083076], dtype=float32),
#  array([0.04980487, 0.22545442, 0.11347457, 0.7100047 ], dtype=float32),
#  array([0.04921092, 0.22881803, 0.11749192, 0.7185603 ], dtype=float32),
#  array([0.04878078, 0.23216335, 0.12131189, 0.7265107 ], dtype=float32),
#  array([0.04852255, 0.23548509, 0.12496953, 0.73387945], dtype=float32),
#  array([0.04843741, 0.23878075, 0.12849373, 0.7406961 ], dtype=float32),
#  array([0.04852356, 0.2420502 , 0.13190949, 0.74699306], dtype=float32),
# ...

# %%
scaled_test
# Out:
# array([[0.12346319, 0.25351453, 0.14597778, 0.57239291],
#        [0.1408757 , 0.26897844, 0.17554167, 0.58525474],
#        [0.10437518, 0.23992502, 0.12264167, 0.59247736],
#        ...,
#        [0.61085806, 0.38238051, 0.49674444, 0.23540197],
#        [0.6981231 , 0.42830366, 0.67177222, 0.23417968],
#        [0.7826696 , 0.45454545, 0.77199444, 0.22854047]])

# %% [markdown]
# **Inverse Transformations and Compare**

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[ 187.59200585,    4.57895042,  270.09984255,  225.27671189],
#        [ 190.34169328,    4.65714849,  294.45853829,  231.90401779],
#        [ 191.18359822,    4.73187092,  318.02963018,  236.75912572],
#        ...,
#        [2124.80329805,   13.00301207, 2632.13367462,  144.05704746],
#        [2125.29190696,   13.00566793, 2632.58042336,  144.10118344],
#        [2125.77750772,   13.00829708, 2633.02330971,  144.14362436]])

# %%
test
# Out:
#                      LV ActivePower (kW)  ...  Wind Direction (°)
# Date/Time                                 ...
# 2018-12-29 00:00:00               444.11  ...              206.05
# 2018-12-29 00:10:00               506.88  ...              210.68
# 2018-12-29 00:20:00               375.30  ...              213.28
# 2018-12-29 00:30:00               442.25  ...              207.25
# 2018-12-29 00:40:00               481.73  ...              206.86
# ...                                  ...  ...                 ...
# 2018-12-31 23:10:00              2963.98  ...               80.50
# 2018-12-31 23:20:00              1684.35  ...               84.06
# 2018-12-31 23:30:00              2201.11  ...               84.74
# 2018-12-31 23:40:00              2515.69  ...               84.30
# 2018-12-31 23:50:00              2820.47  ...               82.27
#
# [432 rows x 4 columns]

# %%
true_predictions = pd.DataFrame(data=true_predictions,columns=test.columns)

# %%
true_predictions
# Out:
#      LV ActivePower (kW)  ...  Wind Direction (°)
# 0             187.592006  ...          225.276712
# 1             190.341693  ...          231.904018
# 2             191.183598  ...          236.759126
# 3             189.851607  ...          241.036518
# 4             187.280663  ...          245.013412
# ..                   ...  ...                 ...
# 427          2123.815767  ...          143.963690
# 428          2124.310822  ...          144.011216
# 429          2124.803298  ...          144.057047
# 430          2125.291907  ...          144.101183
# 431          2125.777508  ...          144.143624
#
# [432 rows x 4 columns]

# %%
from tensorflow.keras.models import load_model

# %%
model.save("multiproj.h5")

# %%
test.plot(figsize=(20,11))
true_predictions.plot()

# %%
df.columns
# Out:
# Index(['LV ActivePower (kW)', 'Wind Speed (m/s)',
#        'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)'],
#       dtype='object')

# %%
true_predictions=true_predictions.set_index(test.index)

# %%
true_predictions.index
# Out:
# DatetimeIndex(['2018-12-29 00:00:00', '2018-12-29 00:10:00',
#                '2018-12-29 00:20:00', '2018-12-29 00:30:00',
#                '2018-12-29 00:40:00', '2018-12-29 00:50:00',
#                '2018-12-29 01:00:00', '2018-12-29 01:10:00',
#                '2018-12-29 01:20:00', '2018-12-29 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=432, freq=None)

# %%
ax =true_predictions.plot(y='Theoretical_Power_Curve (KWh)',label='Predictions',legend=True,figsize=(50,20))

test.plot(y='Theoretical_Power_Curve (KWh)',label='Testdata',legend=True,ax=ax)

# %%
df.columns
# Out:
# Index(['LV ActivePower (kW)', 'Wind Speed (m/s)',
#        'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)'],
#       dtype='object')

# %%
ax =true_predictions.plot(y='Theoretical_Power_Curve (KWh)',label='Predictions',legend=True,figsize=(50,20))

test.plot(y='Wind Speed (m/s)',label='TestdataWS',legend=True,ax=ax)
test.plot(y='LV ActivePower (kW)',label='TestdataLV',legend=True,ax=ax)
test.plot(y='Wind Direction (°)',label='TestdataWD',legend=True,ax=ax)

# %%
from statsmodels.tools.eval_measures import rmse,mse

error = rmse(true_predictions,test)
print(error)
# Out:
# [1889.62303845    8.99913856 2172.9878785   100.54034224]
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
test.index
# Out:
# DatetimeIndex(['2018-12-29 00:00:00', '2018-12-29 00:10:00',
#                '2018-12-29 00:20:00', '2018-12-29 00:30:00',
#                '2018-12-29 00:40:00', '2018-12-29 00:50:00',
#                '2018-12-29 01:00:00', '2018-12-29 01:10:00',
#                '2018-12-29 01:20:00', '2018-12-29 01:30:00',
#                ...
#                '2018-12-31 22:20:00', '2018-12-31 22:30:00',
#                '2018-12-31 22:40:00', '2018-12-31 22:50:00',
#                '2018-12-31 23:00:00', '2018-12-31 23:10:00',
#                '2018-12-31 23:20:00', '2018-12-31 23:30:00',
#                '2018-12-31 23:40:00', '2018-12-31 23:50:00'],
#               dtype='datetime64[ns]', name='Date/Time', length=432, freq=None)

# %%
df.columns
# Out:
# Index(['LV ActivePower (kW)', 'Wind Speed (m/s)',
#        'Theoretical_Power_Curve (KWh)', 'Wind Direction (°)'],
#       dtype='object')
